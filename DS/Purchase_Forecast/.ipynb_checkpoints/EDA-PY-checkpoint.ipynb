# %%
import pandas as pd

# %%
df = pd.read_csv('expdata.csv')

# %%
df
# Out:
#          loja          cidade ESTADO  clienteloja  cliente  \
# 0           1  BELO HORIZONTE     MG            1   531511
# 1           1  BELO HORIZONTE     MG            1   531571
# 2           1  BELO HORIZONTE     MG            1   531599
# 3           1  BELO HORIZONTE     MG            1   531644
# 4           1  BELO HORIZONTE     MG            1   531644
# ...       ...             ...    ...          ...      ...
# 2956080   888        SALVADOR     BA          999  2229227
# 2956081   888        SALVADOR     BA          999  2302831
# 2956082   888        SALVADOR     BA          999  2344083
# 2956083   888        SALVADOR     BA          999  2359863
# 2956084   888        SALVADOR     BA          999  2684534
#
#                         DescricaoTipo       data  QtdeVendas  ValorPago
# 0                 COTURNO SALTO BAIXO  10/6/2022           1     449.99
# 1                 SCARPIN SALTO BAIXO  4/12/2022           1      59.99
# ...

# %%
df.dtypes
# Out:
# loja               int64
# cidade            object
# ESTADO            object
# clienteloja        int64
# cliente            int64
# DescricaoTipo     object
# data              object
# QtdeVendas         int64
# ValorPago        float64
# dtype: object
